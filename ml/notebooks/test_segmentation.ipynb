# %%
import sys
sys.path.append(r"C:\Users\Admin\Desktop\CropGuard\CropGuard\ml\utils")
from segmentation import segment_leaf
import cv2
import matplotlib.pyplot as plt

# Pick a sample image - swap path to test different ones
test_path = r"C:\Users\Admin\Desktop\CropGuard\CropGuard\ml\data\plantdoc\archive\test\Corn_rust_leaf"
import os
sample_file = os.listdir(test_path)[0]
sample_path = os.path.join(test_path, sample_file)

img = cv2.imread(sample_path)
segmented = segment_leaf(img)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axes[0].set_title("Original")
axes[1].imshow(cv2.cvtColor(segmented, cv2.COLOR_BGR2RGB))
axes[1].set_title("Segmented")
plt.show()
